# %% [markdown]
# <a href="https://colab.research.google.com/github/jungjeeo0428/colab-coding/blob/main/CLI%EA%B2%8C%EC%8B%9C%ED%8C%90%EB%A7%8C%EB%93%A4%EA%B8%B0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# CLI게시판
print("CLI게시판에 오신걸 환영합니다")
while True:
  cmd = input("명령어:")
  if cmd == "exit":
    break
  elif cmd == "write article":
   input("제목:")
   line_text = input("내용:")
   print("내용 1번글 생성")
  else:
    print("You are wrong")


print("==CLI 게시판 종료 ==")
# Out:
# 명령어:article write
# 제목:violence in Krea
# 내용:gender violence Korea
